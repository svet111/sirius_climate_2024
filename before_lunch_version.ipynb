# %% [markdown]
# <a href="https://colab.research.google.com/github/amoniaka-knabino/sirius_climate_2024/blob/main/before_lunch_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression

column_name = ['year', 'mon', 'day', 'hour', 'lat', 'lon', 'hsun', 'slp', 'ta', 'sst', 'td', 'rh', 'icn', 'icl', 'low', 'mid', 'high', 'iw', 'ws', 'wd']
numbers = range(2, 3)

# %%
df_2017 = pd.read_fwf("2017_01_data.fwf", names=column_name)

for n in [str(num).zfill(2) for num in numbers]:
  df_next_file = pd.read_fwf(f"2017_{n}_data.fwf", names=column_name)
  df_2017 = pd.concat([df_2017, df_next_file], axis=0)

# %%
df_2016 = pd.read_fwf("2016_01_data.fwf", names=column_name)

for n in [str(num).zfill(2) for num in numbers]:
  df_next_file = pd.read_fwf(f"2016_{n}_data.fwf", names=column_name)
  df_2016 = pd.concat([df_2016, df_next_file], axis=0)

# %%
y_2017 = df_2017['rh']

df_2017_droped = df_2017.drop(['td', 'rh'], axis=1, inplace=False)
df_2017_droped
# Out:
#         year  mon  day  hour   lat  ...  mid  high  iw    ws     wd
# 0       2017    1    1     0  71.3  ...   10    10  85  13.9   60.0
# 1       2017    1    1     0  69.6  ...   -9    -9 -99   3.0  300.0
# 2       2017    1    1     0  66.0  ...   10    10  65  14.4   10.0
# 3       2017    1    1     0  65.3  ...   10    10  80  15.4  360.0
# 4       2017    1    1     0  64.3  ...   -9    -9 -99  -9.9   -9.9
# ...      ...  ...  ...   ...   ...  ...  ...   ...  ..   ...    ...
# 520823  2017    2    0     0  19.3  ...    7    10 -99  10.3   40.0
# 520824  2017    2    1     0  28.0  ...   10    10   3  17.5  300.0
# 520825  2017    2    1     0  19.7  ...    7    10 -99  10.3   40.0
# 520826  2017    2    1     0  18.7  ...    7    10 -99  10.3   40.0
# 520827  2017    2    1     0  18.1  ...    7    10 -99  -9.9   40.0
#
# [1087546 rows x 18 columns]

# %%
y_2016 = df_2016['rh']

df_2016_droped = df_2016.drop(['td', 'rh'], axis=1, inplace=False)
df_2016_droped
# Out:
#         year  mon  day  hour    lat  ...  mid  high  iw    ws     wd
# 0       2016    1    1     0  69.60  ...   -9    -9 -99   8.0  240.0
# 1       2016    1    1     0  69.07  ...   -9    -9 -99  -9.9   -9.9
# 2       2016    1    1     0  66.00  ...   10    10   2  12.9  160.0
# 3       2016    1    1     0  65.30  ...   10    10   2  12.9  180.0
# 4       2016    1    1     0  64.30  ...   -9    -9 -99  11.3  160.0
# ...      ...  ...  ...   ...    ...  ...  ...   ...  ..   ...    ...
# 432965  2016    2    9     8  17.70  ...   -9    -9 -99   0.0  280.0
# 432966  2016    2    9     8  17.00  ...   -9    -9 -99   4.0  320.0
# 432967  2016    2    9     8  11.70  ...   -9    -9 -99   2.0  110.0
# 432968  2016    2    9     8  11.70  ...   -9    -9 -99   1.0  340.0
# 432969  2016    2    9     8  11.70  ...   -9    -9 -99   4.0   50.0
#
# [899396 rows x 18 columns]

# %% [markdown]
# **Начинаем чистку!**

# %%
use_it = ['icn', 'icl', 'low', 'mid', 'high', 'iw', 'ws', 'wd']

# %%
x_train, y_train = df_2016_droped, y_2016
x_test, y_test = df_2017_droped, y_2017

#x_train = x_train.reshape(-1, 1)

model = LinearRegression().fit(x_train, y_train)

y_pred = model.predict(x_test)

R_2 = r2_score(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
RMSE = root_mean_squared_error(y_test, y_pred)

print('R**2 score:', R_2)
print('Root_MSE:', sqrt(MSE))
print('RMSE:', RMSE)
# Out:
# R**2 score: 0.02121383819789513
# Root_MSE: 0.16964386118400507
# RMSE: 0.16964386118400507

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.8 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
from catboost import CatBoostRegressor, Pool

# %%
model_cat = CatBoostRegressor(iterations=100,
                          depth=2,
                          learning_rate=1,
                          loss_function='RMSE')

#train_pool = Pool(train_data, train_label, cat_features=[0,2,5])
#test_pool = Pool(test_data, cat_features=[0,2,5])

train_pool = Pool(x_train, y_train, cat_features=[])
test_pool = Pool(x_test, y_test, cat_features=[])

model_cat.fit(train_pool)
y_pred_cat = model_cat.predict(test_pool)

R_2_catboost = r2_score(y_test, y_pred_cat)
RMSE_catboost = root_mean_squared_error(y_test, y_pred_cat)

print('R**2 catboost score:', R_2_catboost)
print('RMSE catboost:', RMSE_catboost)
# Out:
# 0:	learn: 0.1387367	total: 199ms	remaining: 19.7s
# 1:	learn: 0.1365723	total: 506ms	remaining: 24.8s
# 2:	learn: 0.1353183	total: 901ms	remaining: 29.1s
# 3:	learn: 0.1341798	total: 1.33s	remaining: 31.8s
# 4:	learn: 0.1334626	total: 1.79s	remaining: 34.1s
# 5:	learn: 0.1329561	total: 2.15s	remaining: 33.6s
# 6:	learn: 0.1322852	total: 2.52s	remaining: 33.5s
# 7:	learn: 0.1318772	total: 2.94s	remaining: 33.8s
# 8:	learn: 0.1314767	total: 3.34s	remaining: 33.8s
# 9:	learn: 0.1312581	total: 3.74s	remaining: 33.6s
# 10:	learn: 0.1309930	total: 4.15s	remaining: 33.6s
# 11:	learn: 0.1306368	total: 4.55s	remaining: 33.4s
# 12:	learn: 0.1302963	total: 4.92s	remaining: 32.9s
# 13:	learn: 0.1297578	total: 5.38s	remaining: 33.1s
# 14:	learn: 0.1293515	total: 5.84s	remaining: 33.1s
# 15:	learn: 0.1285630	total: 6.21s	remaining: 32.6s
# 16:	learn: 0.1280846	total: 6.6s	remaining: 32.2s
# 17:	learn: 0.1276521	total: 6.95s	remaining: 31.6s
# 18:	learn: 0.1273526	total: 7.32s	remaining: 31.2s
# 19:	learn: 0.1271705	total: 7.73s	remaining: 30.9s
# 20:	learn: 0.1270204	total: 7.99s	remaining: 30.1s
# 21:	learn: 0.1268377	total: 8.4s	remaining: 29.8s
# 22:	learn: 0.1264645	total: 8.76s	remaining: 29.3s
# 23:	learn: 0.1263103	total: 9.11s	remaining: 28.8s
# 24:	learn: 0.1260748	total: 9.48s	remaining: 28.4s
# 25:	learn: 0.1256483	total: 9.97s	remaining: 28.4s
# 26:	learn: 0.1254348	total: 10.6s	remaining: 28.6s
# 27:	learn: 0.1252394	total: 10.9s	remaining: 28s
# 28:	learn: 0.1250719	total: 11.1s	remaining: 27.3s
# 29:	learn: 0.1249644	total: 11.4s	remaining: 26.7s
# 30:	learn: 0.1248045	total: 11.8s	remaining: 26.2s
# 31:	learn: 0.1246254	total: 12.2s	remaining: 25.8s
# 32:	learn: 0.1243784	total: 12.5s	remaining: 25.4s
# 33:	learn: 0.1241969	total: 12.9s	remaining: 25s
# 34:	learn: 0.1239487	total: 13.4s	remaining: 24.9s
# 35:	learn: 0.1237112	total: 13.9s	remaining: 24.7s
# 36:	learn: 0.1235665	total: 14.3s	remaining: 24.4s
# 37:	learn: 0.1234470	total: 14.7s	remaining: 24s
# 38:	learn: 0.1232960	total: 15.2s	remaining: 23.9s
# 39:	learn: 0.1231294	total: 15.7s	remaining: 23.5s
# 40:	learn: 0.1230485	total: 16s	remaining: 23s
# 41:	learn: 0.1229787	total: 16.3s	remaining: 22.5s
# 42:	learn: 0.1228848	total: 16.5s	remaining: 21.9s
# 43:	learn: 0.1227990	total: 16.7s	remaining: 21.3s
# 44:	learn: 0.1226169	total: 16.9s	remaining: 20.7s
# 45:	learn: 0.1225080	total: 17.2s	remaining: 20.2s
# 46:	learn: 0.1224226	total: 17.4s	remaining: 19.7s
# 47:	learn: 0.1223012	total: 17.7s	remaining: 19.1s
# 48:	learn: 0.1222456	total: 17.9s	remaining: 18.7s
# 49:	learn: 0.1221859	total: 18.1s	remaining: 18.1s
# 50:	learn: 0.1221476	total: 18.3s	remaining: 17.6s
# 51:	learn: 0.1219915	total: 18.6s	remaining: 17.2s
# 52:	learn: 0.1219270	total: 18.9s	remaining: 16.7s
# 53:	learn: 0.1217936	total: 19.1s	remaining: 16.2s
# 54:	learn: 0.1216724	total: 19.3s	remaining: 15.8s
# 55:	learn: 0.1216178	total: 19.5s	remaining: 15.3s
# 56:	learn: 0.1215846	total: 19.7s	remaining: 14.9s
# 57:	learn: 0.1215124	total: 19.9s	remaining: 14.4s
# 58:	learn: 0.1214642	total: 20s	remaining: 13.9s
# 59:	learn: 0.1213243	total: 20.2s	remaining: 13.5s
# 60:	learn: 0.1212875	total: 20.4s	remaining: 13s
# 61:	learn: 0.1212183	total: 20.6s	remaining: 12.6s
# 62:	learn: 0.1211366	total: 20.8s	remaining: 12.2s
# 63:	learn: 0.1210342	total: 20.9s	remaining: 11.8s
# 64:	learn: 0.1209290	total: 21.1s	remaining: 11.4s
# 65:	learn: 0.1208269	total: 21.3s	remaining: 11s
# 66:	learn: 0.1207442	total: 21.5s	remaining: 10.6s
# 67:	learn: 0.1206855	total: 21.7s	remaining: 10.2s
# 68:	learn: 0.1205676	total: 21.9s	remaining: 9.84s
# 69:	learn: 0.1204542	total: 22.1s	remaining: 9.45s
# 70:	learn: 0.1204117	total: 22.2s	remaining: 9.07s
# 71:	learn: 0.1203602	total: 22.4s	remaining: 8.73s
# 72:	learn: 0.1202636	total: 22.6s	remaining: 8.37s
# 73:	learn: 0.1202233	total: 22.9s	remaining: 8.04s
# 74:	learn: 0.1201569	total: 23.2s	remaining: 7.73s
# 75:	learn: 0.1201202	total: 23.6s	remaining: 7.44s
# 76:	learn: 0.1200698	total: 23.8s	remaining: 7.09s
# 77:	learn: 0.1199963	total: 24s	remaining: 6.77s
# 78:	learn: 0.1198785	total: 24.3s	remaining: 6.45s
# 79:	learn: 0.1198280	total: 24.5s	remaining: 6.12s
# 80:	learn: 0.1197957	total: 24.7s	remaining: 5.79s
# 81:	learn: 0.1197695	total: 24.9s	remaining: 5.46s
# 82:	learn: 0.1196795	total: 25.1s	remaining: 5.14s
# 83:	learn: 0.1196191	total: 25.3s	remaining: 4.82s
# 84:	learn: 0.1195488	total: 25.6s	remaining: 4.52s
# 85:	learn: 0.1194924	total: 25.8s	remaining: 4.21s
# 86:	learn: 0.1194044	total: 26.1s	remaining: 3.9s
# 87:	learn: 0.1193533	total: 26.4s	remaining: 3.6s
# 88:	learn: 0.1193015	total: 26.8s	remaining: 3.31s
# 89:	learn: 0.1192642	total: 27.1s	remaining: 3.01s
# 90:	learn: 0.1192227	total: 27.5s	remaining: 2.72s
# 91:	learn: 0.1191415	total: 27.9s	remaining: 2.42s
# 92:	learn: 0.1190696	total: 28.2s	remaining: 2.13s
# 93:	learn: 0.1190335	total: 28.7s	remaining: 1.83s
# 94:	learn: 0.1189733	total: 29.1s	remaining: 1.53s
# 95:	learn: 0.1188317	total: 29.6s	remaining: 1.23s
# 96:	learn: 0.1186953	total: 30s	remaining: 928ms
# 97:	learn: 0.1184461	total: 30.3s	remaining: 618ms
# 98:	learn: 0.1183883	total: 30.7s	remaining: 310ms
# 99:	learn: 0.1183045	total: 31.1s	remaining: 0us
# R**2 catboost score: 0.10989963381341905
# RMSE catboost: 0.16177586410077355

# %%
#линейная регрессия
#for x in np.array(model.get_feature_importance(prettified=True)):
#    print(x)

# %%
feature_importance = model_cat.get_feature_importance()
feature_names = x_test.columns

# Display feature importance
for name, importance in zip(feature_names, feature_importance):
    print(f"Feature: {name}, Importance: {importance:.2f}")
# Out:
# Feature: year, Importance: 0.00
# Feature: mon, Importance: 1.32
# Feature: day, Importance: 0.97
# Feature: hour, Importance: 0.21
# Feature: lat, Importance: 14.88
# Feature: lon, Importance: 30.33
# Feature: hsun, Importance: 5.09
# Feature: slp, Importance: 18.51
# Feature: ta, Importance: 7.65
# Feature: sst, Importance: 3.65
# Feature: icn, Importance: 1.71
# Feature: icl, Importance: 0.00
# Feature: low, Importance: 0.00
# Feature: mid, Importance: 0.15
# Feature: high, Importance: 0.00
# Feature: iw, Importance: 1.73
# Feature: ws, Importance: 3.49
# Feature: wd, Importance: 10.30
